# %%
import requests

response = requests.post("http://localhost:8000/start_balatro")

# %%
response = requests.post("http://localhost:8000/mouse/move", json={"x": 0.5, "y": 0.5})
if response.status_code == 200:
    print("Mouse moved successfully.")
# Out:
# Mouse moved successfully.

# %%
from IPython.display import Image, display


response = requests.get("http://localhost:8000/screenshot_with_cursor")
display(Image(response.content))
